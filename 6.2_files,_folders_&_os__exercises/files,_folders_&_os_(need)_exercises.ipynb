# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os, glob, shutil

# %% [markdown]
# # Misc

# %%
os.getcwd()

# %%
all_files = glob.glob('.\\**\\**.txt', recursive = True)
txt_files = str([file.split(os.path.sep)[-1] for file in all_files]) #[-1] to get only the file names
txt_files = txt_files.split('-')[1::]
txt_files

# %% [markdown]
# # Exercise 1

# %%
#dont need export cuz its in the same directory

mth_to_no = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

old_name = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

#task 1
file = "oct-08_singapore.txt"
octnew = file.replace('oct-08', '10-08')

print(f'{octnew}')
# Out:
# 10-08_singapore.txt

# %%
# Task 2 - 4
def rename_my_file(old_file_name):
    new_name = []
    original = old_file_name #original file path is located here, no need to type path again
    old_file_name = old_file_name.replace('_', '-')
    old_file_name = old_file_name.split('\\')[2] #split will split them into strings. pick the 3rd index
    new_name = old_file_name.replace(old_file_name[:3], mth_to_no[file[:3]]) #picking the first 3 indexes of the split 3rd index (previous)
    new_name = os.path.join('.', 'os-collaboration-exercise-data', new_name) #defining the new_name path
    shutil.move(original, new_name) #(source path, destination)
    new_name = new_name.split('\\')[2] #split them into strings. pick the 3rd inde
    print(old_file_name,'---->', new_name) #for task 3

directory = os.path.join('.', 'os-collaboration-exercise-data', '**.txt')

for filename in glob.glob(directory): #for every item in 'directory', try rename
    try:
        rename_my_file(filename)
    except:
        print('Sorry pal, an error occured')
# Out:
# apr-01-melbourne.txt ----> 10-01-melbourne.txt
# apr-01-shanghai.txt ----> 10-01-shanghai.txt
# apr-01-singapore.txt ----> 10-01-singapore.txt
# apr-02-cairo.txt ----> 10-02-cairo.txt
# apr-02-jakarta.txt ----> 10-02-jakarta.txt
# apr-02-karachi.txt ----> 10-02-karachi.txt
# apr-02-shanghai.txt ----> 10-02-shanghai.txt
# apr-03-manila.txt ----> 10-03-manila.txt
# apr-03-osaka.txt ----> 10-03-osaka.txt
# apr-03-singapore.txt ----> 10-03-singapore.txt
# apr-03-tokyo.txt ----> 10-03-tokyo.txt
# apr-04-manila.txt ----> 10-04-manila.txt
# apr-04-melbourne.txt ----> 10-04-melbourne.txt
# apr-04-shanghai.txt ----> 10-04-shanghai.txt
# apr-04-singapore.txt ----> 10-04-singapore.txt
# apr-05-karachi.txt ----> 10-05-karachi.txt
# apr-05-melbourne.txt ----> 10-05-melbourne.txt
# apr-05-shanghai.txt ----> 10-05-shanghai.txt
# apr-05-singapore.txt ----> 10-05-singapore.txt
# apr-06-cairo.txt ----> 10-06-cairo.txt
# apr-06-jakarta.txt ----> 10-06-jakarta.txt
# ...

# %%
# Task 5
new_folders = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for folder in new_folders:
    os.mkdir(os.path.join('.', 'os-collaboration-exercise-data', folder)) #asking it to access the os-collab folder, and join 'folder' into os-collab folder

# %%
# Task 6
Cairo = glob.glob('os-collaboration-exercise-data\\*Cairo.*')

for old_cairo in glob.glob('os-collaboration-exercise-data\\*Cairo.*'):
    path_to_destination = os.path.join('.', 'os-collaboration-exercise-data', 'Cairo')
    shutil.copy(old_cairo, path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# Copied file to .\os-collaboration-exercise-data\Cairo
# ...

# %%
# Task 7
all_files = glob.glob('os-collaboration-exercise-data\\*')
cities = ['cairo', 'dhaka', 'jakarta', 'karachi', 'manila', 'melbourne', 'osaka', 'shanghai', 'singapore', 'tokyo']
destinations = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo'] 

for move in all_files:
    for cities in all_files:
        path_to_destination = os.path.join('.', 'os-collaboration-exercise-data', destinations) 
        shuntil.move(cities, path_to_destination)
        print(f'Moved file to {path_to_destination}')


    # for dhaka in all_files:
    #     path_to_destination = os.path.join('.', 'os-collaboration-exercise-data', 'Dhaka') 
    #     shuntil.move(dhaka, path_to_destination)
    #     print(f'Moved file to {path_to_destination}')
# Out:
# ['os-collaboration-exercise-data\\10-01-cairo.txt',
#  'os-collaboration-exercise-data\\10-01-dhaka.txt',
#  'os-collaboration-exercise-data\\10-01-jakarta.txt',
#  'os-collaboration-exercise-data\\10-01-karachi.txt',
#  'os-collaboration-exercise-data\\10-01-manila.txt',
#  'os-collaboration-exercise-data\\10-01-melbourne.txt',
#  'os-collaboration-exercise-data\\10-01-osaka.txt',
#  'os-collaboration-exercise-data\\10-01-shanghai.txt',
#  'os-collaboration-exercise-data\\10-01-singapore.txt',
#  'os-collaboration-exercise-data\\10-01-tokyo.txt',
#  'os-collaboration-exercise-data\\10-02-cairo.txt',
#  'os-collaboration-exercise-data\\10-02-dhaka.txt',
#  'os-collaboration-exercise-data\\10-02-jakarta.txt',
#  'os-collaboration-exercise-data\\10-02-karachi.txt',
#  'os-collaboration-exercise-data\\10-02-manila.txt',
#  'os-collaboration-exercise-data\\10-02-melbourne.txt',
#  'os-collaboration-exercise-data\\10-02-osaka.txt',
#  'os-collaboration-exercise-data\\10-02-shanghai.txt',
# ...
